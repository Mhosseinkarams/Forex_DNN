# %% [markdown]
# # Unsup LSTM Autoencoder - Test
# This notebook tests the LSTM Autoencoder for anomaly detection.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
from pathlib import Path

sys.path.append(str(Path.cwd()))
from train import UnsupLSTMAutoencoder

# %%
ae = UnsupLSTMAutoencoder(sequence_length=24)
X = ae.load_and_preprocess()
if X is not None:
    history = ae.train(X, epochs=5)
    mse = ae.calculate_reconstruction_error(X)
    
    plt.figure(figsize=(12, 6))
    plt.plot(mse)
    plt.title("Reconstruction Error (Anomaly Score)")
    plt.show()
